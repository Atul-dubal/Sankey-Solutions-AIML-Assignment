# %% [markdown]
# # AI/ML Assignment: Academic Study Assistant (RAG)
#
# ## Objective
# This project builds a simple AI-powered study assistant using Retrieval Augmented Generation (RAG).
# It answers questions based on course materials (PDF notes).
#
# ## Subject Chosen
# Software Engineering
#
# ## Approach
# - Load PDF notes
# - Split into chunks
# - Store embeddings in vector database
# - Retrieve relevant content
# - Generate answers using LLM
# - Used Ollama (local LLM) instead of OpenAI to avoid API cost and rate limits.
# ## Experiment 1: Chunking Strategies Comparison
#
# In this experiment, we compare:
# - Fixed-size chunking
# - Sentence-based chunking
#
# Goal: To check which gives better answers.

# %%
# !pip install langchain langchain-community chromadb sentence-transformers langchain-huggingface
# Out:
# Requirement already satisfied: langchain in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-community in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (0.4.1)
# Requirement already satisfied: chromadb in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: sentence-transformers in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (5.2.3)
# Requirement already satisfied: langchain-huggingface in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.2.16)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.11.10)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.0.47)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.7.9)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.2.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.13.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (0.36.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: packaging>=24.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (26.0)
# Requirement already satisfied: pyproject_hooks in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: certifi in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: filelock in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: flatbuffers in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: greenlet>=1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.7.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mratu\appdata\local\programs\python\python312\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.llms import Ollama

# %%
pdf_files = [
    "data/BSCIT_SE.pdf",
    "data/SE_Book.pdf",
    "data/SE_NOTES_2.pdf",
    "data/SE_NOTES.pdf"
]

docs = []

for file in pdf_files:
    loader = PyPDFLoader(file)
    docs.extend(loader.load())

print("Total pages:", len(docs))
# Out:
# Total pages: 525

# %% [markdown]
# ## Data Analysis
#
# ### Type of Documents
# - PDF lecture notes
#
# ### Structure
# - Headings, paragraphs, bullet points
#
# ### Challenges
# 1. Some formatting is inconsistent
# 2. Diagrams are not included in text
# 3. Some sections are not properly structured

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2"
)

# %%
# Fixed Chunking
splitter_fixed = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks_fixed = splitter_fixed.split_documents(docs)

db_fixed = Chroma.from_documents(chunks_fixed, embeddings)

print("Total Fixed chunks:", len(chunks_fixed))
# Out:
# Total Fixed chunks: 524

# %%
# Sentence Chunking
splitter_sentence = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks_sentence = splitter_sentence.split_documents(docs)

db_sentence = Chroma.from_documents(chunks_sentence, embeddings)
print("Total Sentence chunks:", len(chunks_sentence))
# Out:
# Total Sentence chunks: 2268

# %%
llm = Ollama(model="mistral")
# Out:
# C:\Users\mratu\AppData\Local\Temp\ipykernel_21792\86901005.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="mistral")

# %% [markdown]
# ## Test Questions
#
# 1. What is Software Engineering?
# 2. What is SDLC?
# 3. Explain Agile model
# 4. What is Waterfall model?
# 5. Difference between Agile and Waterfall
# 6. What is testing?
# 7. What is requirement analysis?
# 8. What is design phase?
# 9. What is maintenance phase?
# 10. What is debugging?

# %%
questions = [
    "What is Software Engineering?",
    "What is SDLC?",
    "Explain Agile model",
    "What is Waterfall model?",
    "Difference between Agile and Waterfall",
    "What is software testing?",
    "What is requirement analysis?",
    "What is design phase?",
    "What is maintenance phase?",
    "What is debugging?"
]

for q in questions:

    print("\n====================================")
    print("Question:", q)

    # FIXED CHUNKING
    print("\n----- FIXED CHUNKING -----")
    results = db_fixed.similarity_search(q, k=3)
    context = " ".join([r.page_content for r in results])

    response = llm.invoke(f"""
    Answer clearly and briefly based only on the context below:
    
    Context:
    {context}
    
    Question: {q}
    """)

    print("A:", response)

    # SENTENCE CHUNKING
    print("\n----- SENTENCE CHUNKING -----")
    results = db_sentence.similarity_search(q, k=3)
    context = " ".join([r.page_content for r in results])

    response = llm.invoke(f"""
    Answer clearly and briefly based only on the context below:
    
    Context:
    {context}
    
    Question: {q}
    """)

    print("A:", response)
# Out:
# ====================================
# Question: What is Software Engineering?
#
# ----- FIXED CHUNKING -----
# A:  Software Engineering is a systematic approach to develop, maintain, and manage software products using well-defined scientific principles, methods, and procedures. It includes various aspects such as programming languages, design techniques, testing, maintenance, and development tools.
#
# ----- SENTENCE CHUNKING -----
# A:  Software Engineering is a systematic, disciplined, and scientific approach to develop and maintain software products in an efficient and cost-effective manner. It involves the use of theories, methods, and tools to create a reliable software product. The scope includes programming languages, design techniques, tools, testing, maintenance, and development among other aspects related to software production.
#
# ====================================
# Question: What is SDLC?
#
# ----- FIXED CHUNKING -----
# A:  SDLC stands for Software Development Life Cycle. It's a process followed for a software project within a software organization. This process includes a detailed plan describing the development, maintenance, replacement, alteration, or enhancement of specific software. The life cycle defines a methodology for the overall development and quality improvement of the software.
#
# ----- SENTENCE CHUNKING -----
# A:  SDLC (Software Development Life Cycle) is a process followed for a software project within a software organization. It consists of a detailed plan describing how to develop, maintain, replace, and alter or enhance specific software, with a focus on improving the quality of software and the overall development process. The life cycle defines a methodology for the system's entire existence, from initial conception through implementation, testing, deployment, maintenance, and eventual retirement.
#
# ====================================
# Question: Explain Agile model
#
# ----- FIXED CHUNKING -----
# A:  The Agile model is an iterative approach to software development that focuses on delivering the software in increments to customers. Unlike traditional plan-driven approaches, the functionality of each increment is not predetermined but decided during the development process based on progress and customer's priorities.
#
# The Agile model consists of several phases:
# 1. Begins with customer specification of requirements.
# 2. Progresses through planning, modeling, construction (development), and deployment.
# 3. Release planning looks ahead for several months to decide features for a release of the system.
# 4. Iteration planning focuses on planning the next increment, typically 2 to 4 weeks of work for the team.
# 5. Changes can be submitted and evaluated throughout the process, allowing flexibility in adapting to new requirements or issues.
#
# Agile methods such as Scrum and Extreme Programming are commonly used examples of Agile development. One key advantage is its ability to accommodate changes more easily than traditional models like the Waterfall model, which can encounter problems when real projects don't follow a sequential flow.
#
# ----- SENTENCE CHUNKING -----
# A:  The Agile model is an iterative approach to software development that involves delivering the software in increments to customers. Unlike traditional plan-driven approaches, the functionality of these increments is not pre-planned but decided during development based on progress and customer's priorities. It begins with the specification of requirements, progresses through planning, modeling, construction (development), and ends with deployment. Agile methods like Scrum and Extreme Programming have a two-stage approach to planning: release planning, which looks ahead for several months and decides on the features that should be included in a release of a system, and iteration planning, which focuses on planning the next increment of a system for a short period (typically 2 to 4 weeks). This model allows for flexibility and customer feedback throughout the development process. However, it may encounter problems when real projects don't follow the proposed sequential flow, leading to potential confusion during changes.
#
# ====================================
# Question: What is Waterfall model?
#
# ----- FIXED CHUNKING -----
# A:  The Waterfall model is a linear, sequential software development model that follows a systematic approach from system analysis to maintenance. It includes phases such as requirement gathering and analysis, design, coding, testing, and maintenance. However, it does not allow for feedback or changes during the completed phases. A slight modification of this model is the Iterative Waterfall Model which allows feedback between phases and enables going backward to correct issues or accommodate new requirements.
#
# ----- SENTENCE CHUNKING -----
# A:  The Waterfall model is a linear, sequential software development model that starts at the system level and progresses through analysis, design, coding, testing, and maintenance phases in a systematic manner. However, it does not include feedback or the ability to go back to previous phases once completed. In contrast, the Iterative Waterfall model allows for feedback and the possibility of going back to earlier phases if necessary.
#
# ====================================
# Question: Difference between Agile and Waterfall
#
# ----- FIXED CHUNKING -----
# A:  The main difference between Agile and Waterfall models lies in their approach to software development.
#
# 1. **Agile Model**: It is a flexible, iterative approach that focuses on collaboration, customer satisfaction, and delivering working software frequently (in increments called sprints). It encourages constant feedback from the client throughout the development process, allowing for adaptability and course corrections. Examples include Scrum and Extreme Programming.
#
# 2. **Waterfall Model**: It is a linear, sequential approach that follows a predictive plan from start to finish before moving on to the next phase. Each phase must be completed fully before moving on to the next, making it less adaptable to changes. It heavily emphasizes documentation and generates comprehensive documents for easy maintenance but suffers from potential delays due to lack of client feedback early in the development process.
#
# In summary, Agile is more flexible and iterative with frequent deliveries and client involvement, while Waterfall is linear and predictive with complete documentation and less adaptability to changes.
#
# ----- SENTENCE CHUNKING -----
# A:  Agile and Waterfall are two different methodologies used in Software Development Life Cycle (SDLC).
#
# 1. Waterfall Model: This is a linear sequential model, meaning that each phase must be completed before the next one begins. It follows a documentation-driven approach, with complete and comprehensive documentation generated at each phase. However, it lacks flexibility as feedback is only received once the product is delivered to the client, making it difficult to correct any errors in requirement specification.
#
# 2. Agile Methodology: This model is iterative and incremental, meaning that development takes place in short cycles called iterations or sprints. It emphasizes collaboration between the development team and customers. The Agile approach has a two-stage planning process: release planning (which looks ahead for several months and decides on features for a system's release) and iteration planning (focusing on planning the work for the upcoming sprint). Agile is more flexible as it allows for feedback at various stages, making it easier to correct any errors or adjust priorities based on customer needs.
#
# In summary, the main differences between Agile and Waterfall are their approach to development (iterative vs linear), flexibility (high vs low), and timing of feedback (throughout the process in Agile vs at the end in Waterfall).
#
# ====================================
# Question: What is software testing?
#
# ----- FIXED CHUNKING -----
# A:  Software testing is the process of executing a program or application with the intent of finding software bugs, validating and verifying that a software product matches expected requirements, and identifying errors or gaps in contrast to actual requirements. It involves using manual or automated tools to evaluate one or more properties of interest, and it's an essential part of the engineering, usage, and maintenance process to measure and improve the quality of the being tested.
#
# ----- SENTENCE CHUNKING -----
# A:  Software testing is a process aimed at executing a program or application to find software bugs, validate and verify that a software product matches its expected requirements, and identify errors, gaps, or missing requirements in contrast to actual requirements. It's a concurrent lifecycle process used for measuring and improving the quality of the software being tested.
#
# ====================================
# Question: What is requirement analysis?
#
# ----- FIXED CHUNKING -----
# A:  Requirement Analysis is a process within Requirement Engineering where the System Requirements Document (SRD) is analyzed at a high level concerning the Application Under Test (AUT). It involves testing and validation opportunities, brainstorming sessions, identifying unclear areas in requirements, and prioritizing assessments.
#
# ----- SENTENCE CHUNKING -----
# A:  Requirement analysis is a process in the Requirement Engineering where the team analyzes the System Requirements Document (SRD) for the Application under Test (AUT). It involves high-level testing, identifying functional and non-functional specifications, brainstorming sessions, spotting blind spots or unclear areas, and prioritizing assessments.
#
# ====================================
# Question: What is design phase?
#
# ----- FIXED CHUNKING -----
# A:  The design phase in this context refers to the process of planning and organizing a system or software, which includes two stages: Preliminary (or High-Level) Design and Detailed (or Low-Level) Design. In the Preliminary Design, modules are recognized, relationships between them are identified, interfaces are defined, and the program structure (system architecture) is generated. The Detailed Design phase involves designing the system at a block level based on functional requirements, with an emphasis on minimizing information flow between blocks.
#
# ----- SENTENCE CHUNKING -----
# A:  The design phase in this context refers to the stage where a system is designed at a block level, based on functional requirements. This includes both Preliminary (High-Level) design and Detailed (Low-Level) design phases. The Preliminary design focuses on recognizing modules, their relationships, identifying interfaces, and generating the program structure or system architecture. The Detailed (Low-Level) design further refines this by designing blocks for different functions, with an emphasis on minimizing information flow between blocks.
#
# ====================================
# Question: What is maintenance phase?
#
# ----- FIXED CHUNKING -----
# A:  The Maintenance phase in the software life cycle is the longest phase where the system is installed and put into practical use. It involves correcting errors, improving the implementation of system units, and enhancing the system's services as new requirements are discovered.
#
# ----- SENTENCE CHUNKING -----
# A:  The maintenance phase is the longest phase of the software life cycle where the system is installed and put into practical use. Maintenance involves correcting errors, improving the implementation of system units, and enhancing the system's services as new requirements are discovered.
#
# ====================================
# Question: What is debugging?
#
# ----- FIXED CHUNKING -----
# A:  Debugging is the process that occurs after successful testing, where the goal is to identify and correct software errors (or bugs). It involves assessing the difference between expected and actual performance of a program, which can help uncover the underlying cause of an issue. Debugging is considered more of an art than a science due to its reliance on intuition and human insight, as well as the variety of strategies used for effective debugging.
#
# ----- SENTENCE CHUNKING -----
# A:  Debugging is a process aimed at finding and correcting the cause of a software error, which occurs as a consequence of successful testing. It involves matching symptoms with causes to lead to error correction. The difficulty in debugging arises due to factors such as geographical distance between symptom and cause, temporary disappearance of symptoms, non-errors causing symptoms, human errors that are hard to trace, timing problems, intermittent symptoms, distributed causes across multiple tasks, and difficulties in accurately reproducing input conditions. Debugging strategies include brute force, backtracking, and cause elimination. Brute force is the most commonly used but least efficient method, which involves executing a program with the intention of finding bugs or errors.

# %% [markdown]
# ## Analysis
#
# Sentence chunking performs better as it preserves complete sentences and context.
# Fixed chunking sometimes splits important information.
# Therefore, sentence-based chunking is more effective for this dataset.
#
# ## Results Summary
#
# | Question Type | Fixed Chunking | Sentence Chunking |
# |--------------|--------------|------------------|
# | Definitions | Good | Good |
# | Conceptual | Good | Better |
# | Detailed Explanation | Average | Excellent |
# | Overall | Good | Better |
